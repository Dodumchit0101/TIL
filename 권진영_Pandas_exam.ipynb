# %% [markdown]
# ## kgmyh@naver.com

# %% [markdown]
# # Seoul_report.csv 읽기
# + 서울시 주민등록인구 (구별) 통계 - [서울열린데이터광장 ](http://data.seoul.go.kr/dataList/datasetView.do?serviceKind=2&infId=419&stcSrl=419&srvType=S)

# %% [markdown]
# ## CSV 파일 읽기
# - Seoul_report.csv 파일의 내용을 DataFrame으로 읽고 변수에 대입

# %%
import pandas as pd
import numpy as np

# %%
report = pd.read_csv('seoul_report.txt', sep='\t', engine='python', encoding='utf-8')
report
# Out:
#       기간   자치구         세대         인구       인구.1       인구.2       인구.3  \
# 0     기간   자치구         세대         합계         합계         합계        한국인
# 1     기간   자치구         세대          계         남자         여자          계
# 2   2020    합계  4,417,954  9,911,088  4,816,522  5,094,566  9,668,465
# 3   2020   종로구     75,003    158,996     76,876     82,120    149,384
# 4   2020    중구     63,686    134,635     65,776     68,859    125,240
# 5   2020   용산구    113,093    244,645    118,835    125,810    230,040
# 6   2020   성동구    135,870    300,505    146,424    154,081    293,556
# 7   2020   광진구    167,427    360,109    173,000    187,109    346,682
# 8   2020  동대문구    167,598    357,014    175,322    181,692    342,837
# 9   2020   중랑구    185,920    399,562    197,118    202,444    394,702
# 10  2020   성북구    195,396    447,056    214,658    232,398    437,153
# 11  2020   강북구    145,896    311,569    151,466    160,103    308,055
# 12  2020   도봉구    139,114    327,361    159,420    167,941    325,257
# 13  2020   노원구    218,270    527,032    254,188    272,844    523,037
# 14  2020   은평구    213,914    484,043    231,998    252,045    479,835
# 15  2020  서대문구    144,838    322,952    153,152    169,800    312,173
# 16  2020   마포구    178,482    381,858    178,977    202,881    371,890
# 17  2020   양천구    180,633    457,781    224,379    233,402    454,251
# 18  2020   강서구    266,982    585,901    282,686    303,215    580,185
# 19  2020   구로구    180,531    432,488    215,424    217,064    404,408
# 20  2020   금천구    114,715    247,835    126,141    121,694    231,733
# 21  2020  영등포구    184,714    407,367    202,969    204,398    379,480
# 22  2020   동작구    184,229    401,572    193,718    207,854    391,220
# 23  2020   관악구    274,811    509,803    255,211    254,592    495,060
# 24  2020   서초구    173,502    429,025    205,282    223,743    425,126
# 25  2020   강남구    234,872    544,055    260,378    283,677    539,231
# 26  2020   송파구    281,959    673,926    325,080    348,846    667,960
# 27  2020   강동구    196,499    463,998    228,044    235,954    459,970
#
#          인구.4       인구.5     인구.6     인구.7     인구.8  세대당인구   65세이상고령자
# 0         한국인        한국인    등록외국인    등록외국인    등록외국인  세대당인구   65세이상고령자
# 1          남자         여자        계       남자       여자  세대당인구   65세이상고령자
# 2   4,701,723  4,966,742  242,623  114,799  127,824   2.19  1,568,331
# 3      72,635     76,749    9,612    4,241    5,371   1.99     28,507
# 4      61,222     64,018    9,395    4,554    4,841   1.97     24,495
# 5     110,722    119,318   14,605    8,113    6,492   2.03     40,247
# 6     143,387    150,169    6,949    3,037    3,912   2.16     45,603
# 7     167,310    179,372   13,427    5,690    7,737   2.07     50,560
# 8     169,769    173,068   14,177    5,553    8,624   2.05     61,796
# 9     195,165    199,537    4,860    1,953    2,907   2.12     69,447
# 10    210,810    226,343    9,903    3,848    6,055   2.24     73,770
# 11    150,143    157,912    3,514    1,323    2,191   2.11     63,422
# 12    158,620    166,637    2,104      800    1,304   2.34     62,059
# 13    252,383    270,654    3,995    1,805    2,190    2.4     85,489
# 14    230,279    249,556    4,208    1,719    2,489   2.24     85,187
# 15    149,360    162,813   10,779    3,792    6,987   2.16     54,204
# 16    175,150    196,740    9,968    3,827    6,141   2.08     54,331
# 17    222,824    231,427    3,530    1,555    1,975   2.51     65,670
# 18    280,034    300,151    5,716    2,652    3,064   2.17     88,984
# 19    199,673    204,735   28,080   15,751   12,329   2.24     70,198
# 20    117,226    114,507   16,102    8,915    7,187   2.02     39,842
# 21    187,647    191,833   27,887   15,322   12,565   2.05     61,688
# 22    189,152    202,068   10,352    4,566    5,786   2.12     65,190
# 23    248,339    246,721   14,743    6,872    7,871    1.8     78,875
# 24    203,359    221,767    3,899    1,923    1,976   2.45     60,169
# 25    257,999    281,232    4,824    2,379    2,445    2.3     75,096
# 26    322,299    345,661    5,966    2,781    3,185   2.37     93,483
# 27    226,216    233,754    4,028    1,828    2,200   2.34     70,019

# %% [markdown]
# # 열명 변경
# - 읽은 DataFrame에 어떤 컬럼이 있는지 확인하고 열명을 아래와 같이 바꾼다. (이외 열이름은 그대로 유지)
#     - '총합계' : '총인구'
#     - '한국인합계': '한국인'
#     - '외국인합계' : '외국인'
#     - '65세이상고령자' : '고령자'

# %%
report.rename({'인구':'총인구','65세이상고령자':'고령자', '인구.3':'한국인', '인구.6':'외국인'}, axis='columns', inplace=True)
report
# Out:
#       기간   자치구         세대        총인구       인구.1       인구.2        한국인  \
# 0     기간   자치구         세대         합계         합계         합계        한국인
# 1     기간   자치구         세대          계         남자         여자          계
# 2   2020    합계  4,417,954  9,911,088  4,816,522  5,094,566  9,668,465
# 3   2020   종로구     75,003    158,996     76,876     82,120    149,384
# 4   2020    중구     63,686    134,635     65,776     68,859    125,240
# 5   2020   용산구    113,093    244,645    118,835    125,810    230,040
# 6   2020   성동구    135,870    300,505    146,424    154,081    293,556
# 7   2020   광진구    167,427    360,109    173,000    187,109    346,682
# 8   2020  동대문구    167,598    357,014    175,322    181,692    342,837
# 9   2020   중랑구    185,920    399,562    197,118    202,444    394,702
# 10  2020   성북구    195,396    447,056    214,658    232,398    437,153
# 11  2020   강북구    145,896    311,569    151,466    160,103    308,055
# 12  2020   도봉구    139,114    327,361    159,420    167,941    325,257
# 13  2020   노원구    218,270    527,032    254,188    272,844    523,037
# 14  2020   은평구    213,914    484,043    231,998    252,045    479,835
# 15  2020  서대문구    144,838    322,952    153,152    169,800    312,173
# 16  2020   마포구    178,482    381,858    178,977    202,881    371,890
# 17  2020   양천구    180,633    457,781    224,379    233,402    454,251
# 18  2020   강서구    266,982    585,901    282,686    303,215    580,185
# 19  2020   구로구    180,531    432,488    215,424    217,064    404,408
# 20  2020   금천구    114,715    247,835    126,141    121,694    231,733
# 21  2020  영등포구    184,714    407,367    202,969    204,398    379,480
# 22  2020   동작구    184,229    401,572    193,718    207,854    391,220
# 23  2020   관악구    274,811    509,803    255,211    254,592    495,060
# 24  2020   서초구    173,502    429,025    205,282    223,743    425,126
# 25  2020   강남구    234,872    544,055    260,378    283,677    539,231
# 26  2020   송파구    281,959    673,926    325,080    348,846    667,960
# 27  2020   강동구    196,499    463,998    228,044    235,954    459,970
#
#          인구.4       인구.5      외국인     인구.7     인구.8  세대당인구        고령자
# 0         한국인        한국인    등록외국인    등록외국인    등록외국인  세대당인구   65세이상고령자
# 1          남자         여자        계       남자       여자  세대당인구   65세이상고령자
# 2   4,701,723  4,966,742  242,623  114,799  127,824   2.19  1,568,331
# 3      72,635     76,749    9,612    4,241    5,371   1.99     28,507
# 4      61,222     64,018    9,395    4,554    4,841   1.97     24,495
# 5     110,722    119,318   14,605    8,113    6,492   2.03     40,247
# 6     143,387    150,169    6,949    3,037    3,912   2.16     45,603
# 7     167,310    179,372   13,427    5,690    7,737   2.07     50,560
# 8     169,769    173,068   14,177    5,553    8,624   2.05     61,796
# 9     195,165    199,537    4,860    1,953    2,907   2.12     69,447
# 10    210,810    226,343    9,903    3,848    6,055   2.24     73,770
# 11    150,143    157,912    3,514    1,323    2,191   2.11     63,422
# 12    158,620    166,637    2,104      800    1,304   2.34     62,059
# 13    252,383    270,654    3,995    1,805    2,190    2.4     85,489
# 14    230,279    249,556    4,208    1,719    2,489   2.24     85,187
# 15    149,360    162,813   10,779    3,792    6,987   2.16     54,204
# 16    175,150    196,740    9,968    3,827    6,141   2.08     54,331
# 17    222,824    231,427    3,530    1,555    1,975   2.51     65,670
# 18    280,034    300,151    5,716    2,652    3,064   2.17     88,984
# 19    199,673    204,735   28,080   15,751   12,329   2.24     70,198
# 20    117,226    114,507   16,102    8,915    7,187   2.02     39,842
# 21    187,647    191,833   27,887   15,322   12,565   2.05     61,688
# 22    189,152    202,068   10,352    4,566    5,786   2.12     65,190
# 23    248,339    246,721   14,743    6,872    7,871    1.8     78,875
# 24    203,359    221,767    3,899    1,923    1,976   2.45     60,169
# 25    257,999    281,232    4,824    2,379    2,445    2.3     75,096
# 26    322,299    345,661    5,966    2,781    3,185   2.37     93,483
# 27    226,216    233,754    4,028    1,828    2,200   2.34     70,019

# %% [markdown]
# # 사용할 열들만 추출
# - 자치구, 총인구, 한국인, 외국인, 고령자 열만 가지는 dataframe 생성
#     - shape이 (5, n) 이 되도록

# %%
report[['자치구', '총인구', '한국인', '외국인']]
# Out:
#      자치구        총인구        한국인      외국인
# 0    자치구         합계        한국인    등록외국인
# 1    자치구          계          계        계
# 2     합계  9,911,088  9,668,465  242,623
# 3    종로구    158,996    149,384    9,612
# 4     중구    134,635    125,240    9,395
# 5    용산구    244,645    230,040   14,605
# 6    성동구    300,505    293,556    6,949
# 7    광진구    360,109    346,682   13,427
# 8   동대문구    357,014    342,837   14,177
# 9    중랑구    399,562    394,702    4,860
# 10   성북구    447,056    437,153    9,903
# 11   강북구    311,569    308,055    3,514
# 12   도봉구    327,361    325,257    2,104
# 13   노원구    527,032    523,037    3,995
# 14   은평구    484,043    479,835    4,208
# 15  서대문구    322,952    312,173   10,779
# 16   마포구    381,858    371,890    9,968
# 17   양천구    457,781    454,251    3,530
# 18   강서구    585,901    580,185    5,716
# 19   구로구    432,488    404,408   28,080
# 20   금천구    247,835    231,733   16,102
# 21  영등포구    407,367    379,480   27,887
# 22   동작구    401,572    391,220   10,352
# 23   관악구    509,803    495,060   14,743
# 24   서초구    429,025    425,126    3,899
# 25   강남구    544,055    539,231    4,824
# 26   송파구    673,926    667,960    5,966
# 27   강동구    463,998    459,970    4,028

# %% [markdown]
# # DataFrame 개괄 정보 조회
# 1. 몇행/몇열인지 조회
# 1. 결측치가 있는지 조회
# 1. DataFrame에 대한 정보(index, columns) 확인
# 1. 상위 5개 행만 조회
# 1. 하위 5개 행만 조회
# 1. 컬럼별 통계량 요약 조회

# %%
#1
report.shape
# Out:
# (28, 14)

# %%
#2, #3
report.info()  #결측치 없음
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   기간      28 non-null     object
#  1   자치구     28 non-null     object
#  2   세대      28 non-null     object
#  3   총인구     28 non-null     object
#  4   인구.1    28 non-null     object
#  5   인구.2    28 non-null     object
#  6   한국인     28 non-null     object
#  7   인구.4    28 non-null     object
#  8   인구.5    28 non-null     object
#  9   외국인     28 non-null     object
#  10  인구.7    28 non-null     object
#  11  인구.8    28 non-null     object
#  12  세대당인구   28 non-null     object
#  13  고령자     28 non-null     object
# dtypes: object(14)
# memory usage: 3.2+ KB

# %%
#4, #5
report.head()
# Out:
#      기간  자치구         세대        총인구       인구.1       인구.2        한국인  \
# 0    기간  자치구         세대         합계         합계         합계        한국인
# 1    기간  자치구         세대          계         남자         여자          계
# 2  2020   합계  4,417,954  9,911,088  4,816,522  5,094,566  9,668,465
# 3  2020  종로구     75,003    158,996     76,876     82,120    149,384
# 4  2020   중구     63,686    134,635     65,776     68,859    125,240
#
#         인구.4       인구.5      외국인     인구.7     인구.8  세대당인구        고령자
# 0        한국인        한국인    등록외국인    등록외국인    등록외국인  세대당인구   65세이상고령자
# 1         남자         여자        계       남자       여자  세대당인구   65세이상고령자
# 2  4,701,723  4,966,742  242,623  114,799  127,824   2.19  1,568,331
# 3     72,635     76,749    9,612    4,241    5,371   1.99     28,507
# 4     61,222     64,018    9,395    4,554    4,841   1.97     24,495

# %%
report.tail()
# Out:
#       기간  자치구       세대      총인구     인구.1     인구.2      한국인     인구.4     인구.5  \
# 23  2020  관악구  274,811  509,803  255,211  254,592  495,060  248,339  246,721
# 24  2020  서초구  173,502  429,025  205,282  223,743  425,126  203,359  221,767
# 25  2020  강남구  234,872  544,055  260,378  283,677  539,231  257,999  281,232
# 26  2020  송파구  281,959  673,926  325,080  348,846  667,960  322,299  345,661
# 27  2020  강동구  196,499  463,998  228,044  235,954  459,970  226,216  233,754
#
#        외국인   인구.7   인구.8 세대당인구     고령자
# 23  14,743  6,872  7,871   1.8  78,875
# 24   3,899  1,923  1,976  2.45  60,169
# 25   4,824  2,379  2,445   2.3  75,096
# 26   5,966  2,781  3,185  2.37  93,483
# 27   4,028  1,828  2,200  2.34  70,019

# %%
#6
report.describe()
# Out:
#           기간  자치구  세대      총인구 인구.1     인구.2      한국인     인구.4 인구.5     외국인  \
# count     28   28  28       28   28       28       28       28   28      28
# unique     2   27  27       28   28       28       28       28   28      28
# top     2020  자치구  세대  432,488   남자  254,592  459,970  280,034  한국인  10,352
# freq      26    2   2        1    1        1        1        1    1       1
#
#        인구.7   인구.8 세대당인구       고령자
# count    28     28    28        28
# unique   28     28    21        27
# top      남자  1,975  2.24  65세이상고령자
# freq      1      1     3         2

# %% [markdown]
# # 열이름으로 조회
# 1. 총인구 열의 모든 값들을 조회
# 1. 한국인, 외국인 열의 모든 값들을 조회

# %%
#1
report.loc[:, '총인구']
# Out:
# 0            합계
# 1             계
# 2     9,911,088
# 3       158,996
# 4       134,635
# 5       244,645
# 6       300,505
# 7       360,109
# 8       357,014
# 9       399,562
# 10      447,056
# 11      311,569
# 12      327,361
# 13      527,032
# 14      484,043
# 15      322,952
# 16      381,858
# 17      457,781
# 18      585,901
# 19      432,488
# 20      247,835
# 21      407,367
# 22      401,572
# 23      509,803
# 24      429,025
# 25      544,055
# 26      673,926
# 27      463,998
# Name: 총인구, dtype: object

# %%
#2
report.loc[:, ['한국인', '외국인']]
# Out:
#           한국인      외국인
# 0         한국인    등록외국인
# 1           계        계
# 2   9,668,465  242,623
# 3     149,384    9,612
# 4     125,240    9,395
# 5     230,040   14,605
# 6     293,556    6,949
# 7     346,682   13,427
# 8     342,837   14,177
# 9     394,702    4,860
# 10    437,153    9,903
# 11    308,055    3,514
# 12    325,257    2,104
# 13    523,037    3,995
# 14    479,835    4,208
# 15    312,173   10,779
# 16    371,890    9,968
# 17    454,251    3,530
# 18    580,185    5,716
# 19    404,408   28,080
# 20    231,733   16,102
# 21    379,480   27,887
# 22    391,220   10,352
# 23    495,060   14,743
# 24    425,126    3,899
# 25    539,231    4,824
# 26    667,960    5,966
# 27    459,970    4,028

# %% [markdown]
# # 행기준 조회
# 1. 5번째 행의 데이터를 조회.
# 1. 1, 5, 7, 10 번째 행의 데이터를 조회
# 1. 15 ~ 20 번째 행의 데이터를 조회
# 1. 10~15 행에서 자치구, 총인구, 한국인 열의 값을 조회
# 1. 6, 7, 8 번째 행의 한국인, 외국인 열의 값을 조회

# %%
#1
report.loc[5]
# Out:
# 기간          2020
# 자치구          용산구
# 세대       113,093
# 총인구      244,645
# 인구.1     118,835
# 인구.2     125,810
# 한국인      230,040
# 인구.4     110,722
# 인구.5     119,318
# 외국인       14,605
# 인구.7       8,113
# 인구.8       6,492
# 세대당인구       2.03
# 고령자       40,247
# Name: 5, dtype: object

# %%
#2
report.loc[[1, 5, 7, 10]]
# Out:
#       기간  자치구       세대      총인구     인구.1     인구.2      한국인     인구.4     인구.5  \
# 1     기간  자치구       세대        계       남자       여자        계       남자       여자
# 5   2020  용산구  113,093  244,645  118,835  125,810  230,040  110,722  119,318
# 7   2020  광진구  167,427  360,109  173,000  187,109  346,682  167,310  179,372
# 10  2020  성북구  195,396  447,056  214,658  232,398  437,153  210,810  226,343
#
#        외국인   인구.7   인구.8  세대당인구       고령자
# 1        계     남자     여자  세대당인구  65세이상고령자
# 5   14,605  8,113  6,492   2.03    40,247
# 7   13,427  5,690  7,737   2.07    50,560
# 10   9,903  3,848  6,055   2.24    73,770

# %%
#3
report.loc[15:20]
# Out:
#       기간   자치구       세대      총인구     인구.1     인구.2      한국인     인구.4     인구.5  \
# 15  2020  서대문구  144,838  322,952  153,152  169,800  312,173  149,360  162,813
# 16  2020   마포구  178,482  381,858  178,977  202,881  371,890  175,150  196,740
# 17  2020   양천구  180,633  457,781  224,379  233,402  454,251  222,824  231,427
# 18  2020   강서구  266,982  585,901  282,686  303,215  580,185  280,034  300,151
# 19  2020   구로구  180,531  432,488  215,424  217,064  404,408  199,673  204,735
# 20  2020   금천구  114,715  247,835  126,141  121,694  231,733  117,226  114,507
#
#        외국인    인구.7    인구.8 세대당인구     고령자
# 15  10,779   3,792   6,987  2.16  54,204
# 16   9,968   3,827   6,141  2.08  54,331
# 17   3,530   1,555   1,975  2.51  65,670
# 18   5,716   2,652   3,064  2.17  88,984
# 19  28,080  15,751  12,329  2.24  70,198
# 20  16,102   8,915   7,187  2.02  39,842

# %%
#4
report.loc[10:15, ['자치구', '총인구', '한국인']]
# Out:
#      자치구      총인구      한국인
# 10   성북구  447,056  437,153
# 11   강북구  311,569  308,055
# 12   도봉구  327,361  325,257
# 13   노원구  527,032  523,037
# 14   은평구  484,043  479,835
# 15  서대문구  322,952  312,173

# %%
#5
report.loc[6:8, ['한국인', '외국인']]
# Out:
#        한국인     외국인
# 6  293,556   6,949
# 7  346,682  13,427
# 8  342,837  14,177

# %% [markdown]
# # index 이름 지정
# 1. '자치구' 열을 index로 설정
# 1. 데이터 프레임의 index이름 조회
# 1. 강남구 행 조회
# 1. 종로구, 성동구, 서대문구 행 조회
# 1. 노원구 ~ 금천구 조회
# 1. 종로구의 한국인,외국인 열의 값 조회
# 1. 도봉구, 노원구, 송파구의 총인구와 고령자 열의 값 조회

# %%
#1
report.set_index('자치구', inplace=True)

# %%
report
# Out:
#         기간         세대        총인구       인구.1       인구.2        한국인       인구.4  \
# 자치구
# 자치구     기간         세대         합계         합계         합계        한국인        한국인
# 자치구     기간         세대          계         남자         여자          계         남자
# 합계    2020  4,417,954  9,911,088  4,816,522  5,094,566  9,668,465  4,701,723
# 종로구   2020     75,003    158,996     76,876     82,120    149,384     72,635
# 중구    2020     63,686    134,635     65,776     68,859    125,240     61,222
# 용산구   2020    113,093    244,645    118,835    125,810    230,040    110,722
# 성동구   2020    135,870    300,505    146,424    154,081    293,556    143,387
# 광진구   2020    167,427    360,109    173,000    187,109    346,682    167,310
# 동대문구  2020    167,598    357,014    175,322    181,692    342,837    169,769
# 중랑구   2020    185,920    399,562    197,118    202,444    394,702    195,165
# 성북구   2020    195,396    447,056    214,658    232,398    437,153    210,810
# 강북구   2020    145,896    311,569    151,466    160,103    308,055    150,143
# 도봉구   2020    139,114    327,361    159,420    167,941    325,257    158,620
# 노원구   2020    218,270    527,032    254,188    272,844    523,037    252,383
# 은평구   2020    213,914    484,043    231,998    252,045    479,835    230,279
# 서대문구  2020    144,838    322,952    153,152    169,800    312,173    149,360
# 마포구   2020    178,482    381,858    178,977    202,881    371,890    175,150
# 양천구   2020    180,633    457,781    224,379    233,402    454,251    222,824
# 강서구   2020    266,982    585,901    282,686    303,215    580,185    280,034
# 구로구   2020    180,531    432,488    215,424    217,064    404,408    199,673
# 금천구   2020    114,715    247,835    126,141    121,694    231,733    117,226
# 영등포구  2020    184,714    407,367    202,969    204,398    379,480    187,647
# 동작구   2020    184,229    401,572    193,718    207,854    391,220    189,152
# 관악구   2020    274,811    509,803    255,211    254,592    495,060    248,339
# 서초구   2020    173,502    429,025    205,282    223,743    425,126    203,359
# 강남구   2020    234,872    544,055    260,378    283,677    539,231    257,999
# 송파구   2020    281,959    673,926    325,080    348,846    667,960    322,299
# 강동구   2020    196,499    463,998    228,044    235,954    459,970    226,216
#
#            인구.5      외국인     인구.7     인구.8  세대당인구        고령자
# 자치구
# 자치구         한국인    등록외국인    등록외국인    등록외국인  세대당인구   65세이상고령자
# 자치구          여자        계       남자       여자  세대당인구   65세이상고령자
# 합계    4,966,742  242,623  114,799  127,824   2.19  1,568,331
# 종로구      76,749    9,612    4,241    5,371   1.99     28,507
# 중구       64,018    9,395    4,554    4,841   1.97     24,495
# 용산구     119,318   14,605    8,113    6,492   2.03     40,247
# 성동구     150,169    6,949    3,037    3,912   2.16     45,603
# 광진구     179,372   13,427    5,690    7,737   2.07     50,560
# 동대문구    173,068   14,177    5,553    8,624   2.05     61,796
# 중랑구     199,537    4,860    1,953    2,907   2.12     69,447
# 성북구     226,343    9,903    3,848    6,055   2.24     73,770
# 강북구     157,912    3,514    1,323    2,191   2.11     63,422
# 도봉구     166,637    2,104      800    1,304   2.34     62,059
# 노원구     270,654    3,995    1,805    2,190    2.4     85,489
# 은평구     249,556    4,208    1,719    2,489   2.24     85,187
# 서대문구    162,813   10,779    3,792    6,987   2.16     54,204
# 마포구     196,740    9,968    3,827    6,141   2.08     54,331
# 양천구     231,427    3,530    1,555    1,975   2.51     65,670
# 강서구     300,151    5,716    2,652    3,064   2.17     88,984
# 구로구     204,735   28,080   15,751   12,329   2.24     70,198
# 금천구     114,507   16,102    8,915    7,187   2.02     39,842
# 영등포구    191,833   27,887   15,322   12,565   2.05     61,688
# 동작구     202,068   10,352    4,566    5,786   2.12     65,190
# 관악구     246,721   14,743    6,872    7,871    1.8     78,875
# 서초구     221,767    3,899    1,923    1,976   2.45     60,169
# 강남구     281,232    4,824    2,379    2,445    2.3     75,096
# 송파구     345,661    5,966    2,781    3,185   2.37     93,483
# 강동구     233,754    4,028    1,828    2,200   2.34     70,019

# %%
#2
report.index
# Out:
# Index(['자치구', '자치구', '합계', '종로구', '중구', '용산구', '성동구', '광진구', '동대문구', '중랑구',
#        '성북구', '강북구', '도봉구', '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구',
#        '금천구', '영등포구', '동작구', '관악구', '서초구', '강남구', '송파구', '강동구'],
#       dtype='object', name='자치구')

# %%
#3
report.loc['강남구']
# Out:
# 기간          2020
# 세대       234,872
# 총인구      544,055
# 인구.1     260,378
# 인구.2     283,677
# 한국인      539,231
# 인구.4     257,999
# 인구.5     281,232
# 외국인        4,824
# 인구.7       2,379
# 인구.8       2,445
# 세대당인구        2.3
# 고령자       75,096
# Name: 강남구, dtype: object

# %%
#4
report.loc[['종로구', '성동구', '서대문구']]
# Out:
#         기간       세대      총인구     인구.1     인구.2      한국인     인구.4     인구.5  \
# 자치구
# 종로구   2020   75,003  158,996   76,876   82,120  149,384   72,635   76,749
# 성동구   2020  135,870  300,505  146,424  154,081  293,556  143,387  150,169
# 서대문구  2020  144,838  322,952  153,152  169,800  312,173  149,360  162,813
#
#          외국인   인구.7   인구.8 세대당인구     고령자
# 자치구
# 종로구    9,612  4,241  5,371  1.99  28,507
# 성동구    6,949  3,037  3,912  2.16  45,603
# 서대문구  10,779  3,792  6,987  2.16  54,204

# %%
#5
report.loc['노원구':'금천구']
# Out:
#         기간       세대      총인구     인구.1     인구.2      한국인     인구.4     인구.5  \
# 자치구
# 노원구   2020  218,270  527,032  254,188  272,844  523,037  252,383  270,654
# 은평구   2020  213,914  484,043  231,998  252,045  479,835  230,279  249,556
# 서대문구  2020  144,838  322,952  153,152  169,800  312,173  149,360  162,813
# 마포구   2020  178,482  381,858  178,977  202,881  371,890  175,150  196,740
# 양천구   2020  180,633  457,781  224,379  233,402  454,251  222,824  231,427
# 강서구   2020  266,982  585,901  282,686  303,215  580,185  280,034  300,151
# 구로구   2020  180,531  432,488  215,424  217,064  404,408  199,673  204,735
# 금천구   2020  114,715  247,835  126,141  121,694  231,733  117,226  114,507
#
#          외국인    인구.7    인구.8 세대당인구     고령자
# 자치구
# 노원구    3,995   1,805   2,190   2.4  85,489
# 은평구    4,208   1,719   2,489  2.24  85,187
# 서대문구  10,779   3,792   6,987  2.16  54,204
# 마포구    9,968   3,827   6,141  2.08  54,331
# 양천구    3,530   1,555   1,975  2.51  65,670
# 강서구    5,716   2,652   3,064  2.17  88,984
# 구로구   28,080  15,751  12,329  2.24  70,198
# 금천구   16,102   8,915   7,187  2.02  39,842

# %%
#6
report.loc['종로구', ['한국인', '외국인']]
# Out:
# 한국인    149,384
# 외국인      9,612
# Name: 종로구, dtype: object

# %%
#7
report.loc[['도봉구', '노원구', '송파구'], ['총인구', '고령자']]
# Out:
#          총인구     고령자
# 자치구
# 도봉구  327,361  62,059
# 노원구  527,032  85,489
# 송파구  673,926  93,483

# %% [markdown]
# # Boolean 인덱싱 - 조건으로 조회
# 1. 총인구가 500,000 이상인 행 조회
# 1. 외국인이 15,000 이상인 행의 한국인, 외국인 열 조회
# 1. 외국인이 고령자보다 많은 행을 조회 (없으므로 아무 행도 안나오는게 정상임)
# 1. 고령자수가 60,000 ~ 70,000 인 행 조회
# 1. 외국인이 15,000 이상이고 고령자가 50,000 이상인 행을 조회

# %%
#!
report.loc['총인구']>=500000
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._unpack_bool_indexer()
#
# KeyError: '총인구'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-16282b896c19> in <module>
#       1 #!
# ----> 2 report.loc['총인구']>=500000
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1108         # fall thru to straight lookup
#    1109         self._validate_key(key, axis)
# -> 1110         return self._get_label(key, axis=axis)
#    1111
#    1112     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#    1057     def _get_label(self, label, axis: int):
#    1058         # GH#5667 this will fail if the label is not present in the axis.
# -> 1059         return self.obj.xs(label, axis=axis)
#    1060
#    1061     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3489             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3490         else:
# -> 3491             loc = self.index.get_loc(key)
#    3492
#    3493             if isinstance(loc, np.ndarray):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: '총인구'

# %%
#2
report[['한국인', '외국인'],'외국인'>=15000]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-5ce7855b28e2> in <module>
#       1 #2
# ----> 2 report[['한국인', '외국인'],'외국인'>=15000]
#
# TypeError: '>=' not supported between instances of 'str' and 'int'

# %%
#3
report.loc['외국인'>'고령자']

# %%
#4
report.loc[60000<='고령자'<=70000]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-7cd02416ca35> in <module>
#       1 #4
# ----> 2 report.loc[60000<='고령자'<=70000]
#
# TypeError: '<=' not supported between instances of 'int' and 'str'

# %%
#5
(report['외국인']>=15000) & (report['고령자']>=50000)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-f3fbea941326> in <module>
#       1 #5
# ----> 2 (report['외국인']>=15000) & (report['고령자']>=50000)
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(self, other)
#     368         rvalues = extract_array(other, extract_numpy=True)
#     369
# --> 370         res_values = comparison_op(lvalues, rvalues, op)
#     371
#     372         return self._construct_result(res_values, name=res_name)
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in comparison_op(left, right, op)
#     242
#     243     elif is_object_dtype(lvalues.dtype):
# --> 244         res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     245
#     246     else:
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in comp_method_OBJECT_ARRAY(op, x, y)
#      54         result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      55     else:
# ---> 56         result = libops.scalar_compare(x.ravel(), y, op)
#      57     return result.reshape(x.shape)
#      58
#
# pandas\_libs\ops.pyx in pandas._libs.ops.scalar_compare()
#
# TypeError: '>=' not supported between instances of 'str' and 'int'

# %% [markdown]
# # 정렬
# 1. 자치구컬럼 기준 오름차순 순으로 정렬
# 1. 자치구컬럼 기준 내림차순 순으로 정렬
# 1. 외국인이 많이 있는 순으로 정렬
# 1. 한국인이 많이 있는 순서로 정렬하고 혹시 같으면 고령자가 적은 순으로 2차 정렬
# 1. 합계를 지우고 총인구 내림차순으로 정렬

# %%
#!
report.sort_index()
# Out:
#         기간         세대        총인구       인구.1       인구.2        한국인       인구.4  \
# 자치구
# 강남구   2020    234,872    544,055    260,378    283,677    539,231    257,999
# 강동구   2020    196,499    463,998    228,044    235,954    459,970    226,216
# 강북구   2020    145,896    311,569    151,466    160,103    308,055    150,143
# 강서구   2020    266,982    585,901    282,686    303,215    580,185    280,034
# 관악구   2020    274,811    509,803    255,211    254,592    495,060    248,339
# 광진구   2020    167,427    360,109    173,000    187,109    346,682    167,310
# 구로구   2020    180,531    432,488    215,424    217,064    404,408    199,673
# 금천구   2020    114,715    247,835    126,141    121,694    231,733    117,226
# 노원구   2020    218,270    527,032    254,188    272,844    523,037    252,383
# 도봉구   2020    139,114    327,361    159,420    167,941    325,257    158,620
# 동대문구  2020    167,598    357,014    175,322    181,692    342,837    169,769
# 동작구   2020    184,229    401,572    193,718    207,854    391,220    189,152
# 마포구   2020    178,482    381,858    178,977    202,881    371,890    175,150
# 서대문구  2020    144,838    322,952    153,152    169,800    312,173    149,360
# 서초구   2020    173,502    429,025    205,282    223,743    425,126    203,359
# 성동구   2020    135,870    300,505    146,424    154,081    293,556    143,387
# 성북구   2020    195,396    447,056    214,658    232,398    437,153    210,810
# 송파구   2020    281,959    673,926    325,080    348,846    667,960    322,299
# 양천구   2020    180,633    457,781    224,379    233,402    454,251    222,824
# 영등포구  2020    184,714    407,367    202,969    204,398    379,480    187,647
# 용산구   2020    113,093    244,645    118,835    125,810    230,040    110,722
# 은평구   2020    213,914    484,043    231,998    252,045    479,835    230,279
# 자치구     기간         세대          계         남자         여자          계         남자
# 자치구     기간         세대         합계         합계         합계        한국인        한국인
# 종로구   2020     75,003    158,996     76,876     82,120    149,384     72,635
# 중구    2020     63,686    134,635     65,776     68,859    125,240     61,222
# 중랑구   2020    185,920    399,562    197,118    202,444    394,702    195,165
# 합계    2020  4,417,954  9,911,088  4,816,522  5,094,566  9,668,465  4,701,723
#
#            인구.5      외국인     인구.7     인구.8  세대당인구        고령자
# 자치구
# 강남구     281,232    4,824    2,379    2,445    2.3     75,096
# 강동구     233,754    4,028    1,828    2,200   2.34     70,019
# 강북구     157,912    3,514    1,323    2,191   2.11     63,422
# 강서구     300,151    5,716    2,652    3,064   2.17     88,984
# 관악구     246,721   14,743    6,872    7,871    1.8     78,875
# 광진구     179,372   13,427    5,690    7,737   2.07     50,560
# 구로구     204,735   28,080   15,751   12,329   2.24     70,198
# 금천구     114,507   16,102    8,915    7,187   2.02     39,842
# 노원구     270,654    3,995    1,805    2,190    2.4     85,489
# 도봉구     166,637    2,104      800    1,304   2.34     62,059
# 동대문구    173,068   14,177    5,553    8,624   2.05     61,796
# 동작구     202,068   10,352    4,566    5,786   2.12     65,190
# 마포구     196,740    9,968    3,827    6,141   2.08     54,331
# 서대문구    162,813   10,779    3,792    6,987   2.16     54,204
# 서초구     221,767    3,899    1,923    1,976   2.45     60,169
# 성동구     150,169    6,949    3,037    3,912   2.16     45,603
# 성북구     226,343    9,903    3,848    6,055   2.24     73,770
# 송파구     345,661    5,966    2,781    3,185   2.37     93,483
# 양천구     231,427    3,530    1,555    1,975   2.51     65,670
# 영등포구    191,833   27,887   15,322   12,565   2.05     61,688
# 용산구     119,318   14,605    8,113    6,492   2.03     40,247
# 은평구     249,556    4,208    1,719    2,489   2.24     85,187
# 자치구          여자        계       남자       여자  세대당인구   65세이상고령자
# 자치구         한국인    등록외국인    등록외국인    등록외국인  세대당인구   65세이상고령자
# 종로구      76,749    9,612    4,241    5,371   1.99     28,507
# 중구       64,018    9,395    4,554    4,841   1.97     24,495
# 중랑구     199,537    4,860    1,953    2,907   2.12     69,447
# 합계    4,966,742  242,623  114,799  127,824   2.19  1,568,331

# %%
#2
report.sort_index(ascending=False)
# Out:
#         기간         세대        총인구       인구.1       인구.2        한국인       인구.4  \
# 자치구
# 합계    2020  4,417,954  9,911,088  4,816,522  5,094,566  9,668,465  4,701,723
# 중랑구   2020    185,920    399,562    197,118    202,444    394,702    195,165
# 중구    2020     63,686    134,635     65,776     68,859    125,240     61,222
# 종로구   2020     75,003    158,996     76,876     82,120    149,384     72,635
# 자치구     기간         세대         합계         합계         합계        한국인        한국인
# 자치구     기간         세대          계         남자         여자          계         남자
# 은평구   2020    213,914    484,043    231,998    252,045    479,835    230,279
# 용산구   2020    113,093    244,645    118,835    125,810    230,040    110,722
# 영등포구  2020    184,714    407,367    202,969    204,398    379,480    187,647
# 양천구   2020    180,633    457,781    224,379    233,402    454,251    222,824
# 송파구   2020    281,959    673,926    325,080    348,846    667,960    322,299
# 성북구   2020    195,396    447,056    214,658    232,398    437,153    210,810
# 성동구   2020    135,870    300,505    146,424    154,081    293,556    143,387
# 서초구   2020    173,502    429,025    205,282    223,743    425,126    203,359
# 서대문구  2020    144,838    322,952    153,152    169,800    312,173    149,360
# 마포구   2020    178,482    381,858    178,977    202,881    371,890    175,150
# 동작구   2020    184,229    401,572    193,718    207,854    391,220    189,152
# 동대문구  2020    167,598    357,014    175,322    181,692    342,837    169,769
# 도봉구   2020    139,114    327,361    159,420    167,941    325,257    158,620
# 노원구   2020    218,270    527,032    254,188    272,844    523,037    252,383
# 금천구   2020    114,715    247,835    126,141    121,694    231,733    117,226
# 구로구   2020    180,531    432,488    215,424    217,064    404,408    199,673
# 광진구   2020    167,427    360,109    173,000    187,109    346,682    167,310
# 관악구   2020    274,811    509,803    255,211    254,592    495,060    248,339
# 강서구   2020    266,982    585,901    282,686    303,215    580,185    280,034
# 강북구   2020    145,896    311,569    151,466    160,103    308,055    150,143
# 강동구   2020    196,499    463,998    228,044    235,954    459,970    226,216
# 강남구   2020    234,872    544,055    260,378    283,677    539,231    257,999
#
#            인구.5      외국인     인구.7     인구.8  세대당인구        고령자
# 자치구
# 합계    4,966,742  242,623  114,799  127,824   2.19  1,568,331
# 중랑구     199,537    4,860    1,953    2,907   2.12     69,447
# 중구       64,018    9,395    4,554    4,841   1.97     24,495
# 종로구      76,749    9,612    4,241    5,371   1.99     28,507
# 자치구         한국인    등록외국인    등록외국인    등록외국인  세대당인구   65세이상고령자
# 자치구          여자        계       남자       여자  세대당인구   65세이상고령자
# 은평구     249,556    4,208    1,719    2,489   2.24     85,187
# 용산구     119,318   14,605    8,113    6,492   2.03     40,247
# 영등포구    191,833   27,887   15,322   12,565   2.05     61,688
# 양천구     231,427    3,530    1,555    1,975   2.51     65,670
# 송파구     345,661    5,966    2,781    3,185   2.37     93,483
# 성북구     226,343    9,903    3,848    6,055   2.24     73,770
# 성동구     150,169    6,949    3,037    3,912   2.16     45,603
# 서초구     221,767    3,899    1,923    1,976   2.45     60,169
# 서대문구    162,813   10,779    3,792    6,987   2.16     54,204
# 마포구     196,740    9,968    3,827    6,141   2.08     54,331
# 동작구     202,068   10,352    4,566    5,786   2.12     65,190
# 동대문구    173,068   14,177    5,553    8,624   2.05     61,796
# 도봉구     166,637    2,104      800    1,304   2.34     62,059
# 노원구     270,654    3,995    1,805    2,190    2.4     85,489
# 금천구     114,507   16,102    8,915    7,187   2.02     39,842
# 구로구     204,735   28,080   15,751   12,329   2.24     70,198
# 광진구     179,372   13,427    5,690    7,737   2.07     50,560
# 관악구     246,721   14,743    6,872    7,871    1.8     78,875
# 강서구     300,151    5,716    2,652    3,064   2.17     88,984
# 강북구     157,912    3,514    1,323    2,191   2.11     63,422
# 강동구     233,754    4,028    1,828    2,200   2.34     70,019
# 강남구     281,232    4,824    2,379    2,445    2.3     75,096

# %%
#3
report.sort_values('외국인')
# Out:
#         기간         세대        총인구       인구.1       인구.2        한국인       인구.4  \
# 자치구
# 동작구   2020    184,229    401,572    193,718    207,854    391,220    189,152
# 서대문구  2020    144,838    322,952    153,152    169,800    312,173    149,360
# 광진구   2020    167,427    360,109    173,000    187,109    346,682    167,310
# 동대문구  2020    167,598    357,014    175,322    181,692    342,837    169,769
# 용산구   2020    113,093    244,645    118,835    125,810    230,040    110,722
# 관악구   2020    274,811    509,803    255,211    254,592    495,060    248,339
# 금천구   2020    114,715    247,835    126,141    121,694    231,733    117,226
# 도봉구   2020    139,114    327,361    159,420    167,941    325,257    158,620
# 합계    2020  4,417,954  9,911,088  4,816,522  5,094,566  9,668,465  4,701,723
# 영등포구  2020    184,714    407,367    202,969    204,398    379,480    187,647
# 구로구   2020    180,531    432,488    215,424    217,064    404,408    199,673
# 강북구   2020    145,896    311,569    151,466    160,103    308,055    150,143
# 양천구   2020    180,633    457,781    224,379    233,402    454,251    222,824
# 서초구   2020    173,502    429,025    205,282    223,743    425,126    203,359
# 노원구   2020    218,270    527,032    254,188    272,844    523,037    252,383
# 강동구   2020    196,499    463,998    228,044    235,954    459,970    226,216
# 은평구   2020    213,914    484,043    231,998    252,045    479,835    230,279
# 강남구   2020    234,872    544,055    260,378    283,677    539,231    257,999
# 중랑구   2020    185,920    399,562    197,118    202,444    394,702    195,165
# 강서구   2020    266,982    585,901    282,686    303,215    580,185    280,034
# 송파구   2020    281,959    673,926    325,080    348,846    667,960    322,299
# 성동구   2020    135,870    300,505    146,424    154,081    293,556    143,387
# 중구    2020     63,686    134,635     65,776     68,859    125,240     61,222
# 종로구   2020     75,003    158,996     76,876     82,120    149,384     72,635
# 성북구   2020    195,396    447,056    214,658    232,398    437,153    210,810
# 마포구   2020    178,482    381,858    178,977    202,881    371,890    175,150
# 자치구     기간         세대          계         남자         여자          계         남자
# 자치구     기간         세대         합계         합계         합계        한국인        한국인
#
#            인구.5      외국인     인구.7     인구.8  세대당인구        고령자
# 자치구
# 동작구     202,068   10,352    4,566    5,786   2.12     65,190
# 서대문구    162,813   10,779    3,792    6,987   2.16     54,204
# 광진구     179,372   13,427    5,690    7,737   2.07     50,560
# 동대문구    173,068   14,177    5,553    8,624   2.05     61,796
# 용산구     119,318   14,605    8,113    6,492   2.03     40,247
# 관악구     246,721   14,743    6,872    7,871    1.8     78,875
# 금천구     114,507   16,102    8,915    7,187   2.02     39,842
# 도봉구     166,637    2,104      800    1,304   2.34     62,059
# 합계    4,966,742  242,623  114,799  127,824   2.19  1,568,331
# 영등포구    191,833   27,887   15,322   12,565   2.05     61,688
# 구로구     204,735   28,080   15,751   12,329   2.24     70,198
# 강북구     157,912    3,514    1,323    2,191   2.11     63,422
# 양천구     231,427    3,530    1,555    1,975   2.51     65,670
# 서초구     221,767    3,899    1,923    1,976   2.45     60,169
# 노원구     270,654    3,995    1,805    2,190    2.4     85,489
# 강동구     233,754    4,028    1,828    2,200   2.34     70,019
# 은평구     249,556    4,208    1,719    2,489   2.24     85,187
# 강남구     281,232    4,824    2,379    2,445    2.3     75,096
# 중랑구     199,537    4,860    1,953    2,907   2.12     69,447
# 강서구     300,151    5,716    2,652    3,064   2.17     88,984
# 송파구     345,661    5,966    2,781    3,185   2.37     93,483
# 성동구     150,169    6,949    3,037    3,912   2.16     45,603
# 중구       64,018    9,395    4,554    4,841   1.97     24,495
# 종로구      76,749    9,612    4,241    5,371   1.99     28,507
# 성북구     226,343    9,903    3,848    6,055   2.24     73,770
# 마포구     196,740    9,968    3,827    6,141   2.08     54,331
# 자치구          여자        계       남자       여자  세대당인구   65세이상고령자
# 자치구         한국인    등록외국인    등록외국인    등록외국인  세대당인구   65세이상고령자

# %%
#4
result = report.sort_values(['한국인'])
result.sort_values('고령자', ascending=False)
# Out:
#         기간         세대        총인구       인구.1       인구.2        한국인       인구.4  \
# 자치구
# 송파구   2020    281,959    673,926    325,080    348,846    667,960    322,299
# 강서구   2020    266,982    585,901    282,686    303,215    580,185    280,034
# 노원구   2020    218,270    527,032    254,188    272,844    523,037    252,383
# 은평구   2020    213,914    484,043    231,998    252,045    479,835    230,279
# 관악구   2020    274,811    509,803    255,211    254,592    495,060    248,339
# 강남구   2020    234,872    544,055    260,378    283,677    539,231    257,999
# 성북구   2020    195,396    447,056    214,658    232,398    437,153    210,810
# 구로구   2020    180,531    432,488    215,424    217,064    404,408    199,673
# 강동구   2020    196,499    463,998    228,044    235,954    459,970    226,216
# 중랑구   2020    185,920    399,562    197,118    202,444    394,702    195,165
# 자치구     기간         세대          계         남자         여자          계         남자
# 자치구     기간         세대         합계         합계         합계        한국인        한국인
# 양천구   2020    180,633    457,781    224,379    233,402    454,251    222,824
# 동작구   2020    184,229    401,572    193,718    207,854    391,220    189,152
# 강북구   2020    145,896    311,569    151,466    160,103    308,055    150,143
# 도봉구   2020    139,114    327,361    159,420    167,941    325,257    158,620
# 동대문구  2020    167,598    357,014    175,322    181,692    342,837    169,769
# 영등포구  2020    184,714    407,367    202,969    204,398    379,480    187,647
# 서초구   2020    173,502    429,025    205,282    223,743    425,126    203,359
# 마포구   2020    178,482    381,858    178,977    202,881    371,890    175,150
# 서대문구  2020    144,838    322,952    153,152    169,800    312,173    149,360
# 광진구   2020    167,427    360,109    173,000    187,109    346,682    167,310
# 성동구   2020    135,870    300,505    146,424    154,081    293,556    143,387
# 용산구   2020    113,093    244,645    118,835    125,810    230,040    110,722
# 금천구   2020    114,715    247,835    126,141    121,694    231,733    117,226
# 종로구   2020     75,003    158,996     76,876     82,120    149,384     72,635
# 중구    2020     63,686    134,635     65,776     68,859    125,240     61,222
# 합계    2020  4,417,954  9,911,088  4,816,522  5,094,566  9,668,465  4,701,723
#
#            인구.5      외국인     인구.7     인구.8  세대당인구        고령자
# 자치구
# 송파구     345,661    5,966    2,781    3,185   2.37     93,483
# 강서구     300,151    5,716    2,652    3,064   2.17     88,984
# 노원구     270,654    3,995    1,805    2,190    2.4     85,489
# 은평구     249,556    4,208    1,719    2,489   2.24     85,187
# 관악구     246,721   14,743    6,872    7,871    1.8     78,875
# 강남구     281,232    4,824    2,379    2,445    2.3     75,096
# 성북구     226,343    9,903    3,848    6,055   2.24     73,770
# 구로구     204,735   28,080   15,751   12,329   2.24     70,198
# 강동구     233,754    4,028    1,828    2,200   2.34     70,019
# 중랑구     199,537    4,860    1,953    2,907   2.12     69,447
# 자치구          여자        계       남자       여자  세대당인구   65세이상고령자
# 자치구         한국인    등록외국인    등록외국인    등록외국인  세대당인구   65세이상고령자
# 양천구     231,427    3,530    1,555    1,975   2.51     65,670
# 동작구     202,068   10,352    4,566    5,786   2.12     65,190
# 강북구     157,912    3,514    1,323    2,191   2.11     63,422
# 도봉구     166,637    2,104      800    1,304   2.34     62,059
# 동대문구    173,068   14,177    5,553    8,624   2.05     61,796
# 영등포구    191,833   27,887   15,322   12,565   2.05     61,688
# 서초구     221,767    3,899    1,923    1,976   2.45     60,169
# 마포구     196,740    9,968    3,827    6,141   2.08     54,331
# 서대문구    162,813   10,779    3,792    6,987   2.16     54,204
# 광진구     179,372   13,427    5,690    7,737   2.07     50,560
# 성동구     150,169    6,949    3,037    3,912   2.16     45,603
# 용산구     119,318   14,605    8,113    6,492   2.03     40,247
# 금천구     114,507   16,102    8,915    7,187   2.02     39,842
# 종로구      76,749    9,612    4,241    5,371   1.99     28,507
# 중구       64,018    9,395    4,554    4,841   1.97     24,495
# 합계    4,966,742  242,623  114,799  127,824   2.19  1,568,331

# %% [markdown]
# # 열 추가 - 파생변수
# 1. 총인구 대비 외국인의 비율을 계산한 값을 **외국인비율** 컬럼을 만들어 넣기 (외국인/총인구 * 100)
# 1. 총인구 대비 고령자의 비율을 계산한 값을 **고령자비율** 컬럼을 만들어 넣기

# %%
#1
report['외국인비율'] = report['외국인'] / report['총인구'] * 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_arithmetic_op(left, right, op, is_cmp)
#     142     try:
# --> 143         result = expressions.evaluate(op, left, right)
#     144     except TypeError:
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     232         if use_numexpr:
# --> 233             return _evaluate(op, op_str, a, b)  # type: ignore
#     234     return _evaluate_standard(op, op_str, a, b)
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     118     if result is None:
# --> 119         result = _evaluate_standard(op, op_str, a, b)
#     120
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
#      67     with np.errstate(all="ignore"):
# ---> 68         return op(a, b)
#      69
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-62d16adf52c2> in <module>
# ----> 1 report['외국인비율'] = report['외국인'] / report['총인구'] * 100
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(left, right)
#     341         lvalues = extract_array(left, extract_numpy=True)
#     342         rvalues = extract_array(right, extract_numpy=True)
# --> 343         result = arithmetic_op(lvalues, rvalues, op)
#     344
#     345         return left._construct_result(result, name=res_name)
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in arithmetic_op(left, right, op)
#     188     else:
#     189         with np.errstate(all="ignore"):
# --> 190             res_values = na_arithmetic_op(lvalues, rvalues, op)
#     191
#     192     return res_values
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_arithmetic_op(left, right, op, is_cmp)
#     148             #  will handle complex numbers incorrectly, see GH#32047
#     149             raise
# --> 150         result = masked_arith_op(left, right, op)
#     151
#     152     if is_cmp and (is_scalar(result) or result is NotImplemented):
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in masked_arith_op(x, y, op)
#      90         if mask.any():
#      91             with np.errstate(all="ignore"):
# ---> 92                 result[mask] = op(xrav[mask], yrav[mask])
#      93
#      94     else:
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %%
#2
report['고령자비율'] = report['고령자'] / report['총인구'] * 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_arithmetic_op(left, right, op, is_cmp)
#     142     try:
# --> 143         result = expressions.evaluate(op, left, right)
#     144     except TypeError:
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     232         if use_numexpr:
# --> 233             return _evaluate(op, op_str, a, b)  # type: ignore
#     234     return _evaluate_standard(op, op_str, a, b)
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     118     if result is None:
# --> 119         result = _evaluate_standard(op, op_str, a, b)
#     120
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
#      67     with np.errstate(all="ignore"):
# ---> 68         return op(a, b)
#      69
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-dc9428f6e55f> in <module>
#       1 #2
# ----> 2 report['고령자비율'] = report['고령자'] / report['총인구'] * 100
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(left, right)
#     341         lvalues = extract_array(left, extract_numpy=True)
#     342         rvalues = extract_array(right, extract_numpy=True)
# --> 343         result = arithmetic_op(lvalues, rvalues, op)
#     344
#     345         return left._construct_result(result, name=res_name)
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in arithmetic_op(left, right, op)
#     188     else:
#     189         with np.errstate(all="ignore"):
# --> 190             res_values = na_arithmetic_op(lvalues, rvalues, op)
#     191
#     192     return res_values
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_arithmetic_op(left, right, op, is_cmp)
#     148             #  will handle complex numbers incorrectly, see GH#32047
#     149             raise
# --> 150         result = masked_arith_op(left, right, op)
#     151
#     152     if is_cmp and (is_scalar(result) or result is NotImplemented):
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in masked_arith_op(x, y, op)
#      90         if mask.any():
#      91             with np.errstate(all="ignore"):
# ---> 92                 result[mask] = op(xrav[mask], yrav[mask])
#      93
#      94     else:
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %% [markdown]
# # 기술 통계정보
# 1. 아래를 조회하는데 합계 행은 빼고 계산한다.
# 1. 총인구 컬럼의 평균, 합계, 중위값, 표준편차, 분산, 데이터개수
# 1. 외국인과 고령자의 평균, 표준편차 조회
# 1. 외국인이 가장 적은 행을 조회

# %%
#평균
report.mean(axis=1, skipna=True)
# Out:
# 자치구
# 자치구    NaN
# 자치구    NaN
# 합계     NaN
# 종로구    NaN
# 중구     NaN
# 용산구    NaN
# 성동구    NaN
# 광진구    NaN
# 동대문구   NaN
# 중랑구    NaN
# 성북구    NaN
# 강북구    NaN
# 도봉구    NaN
# 노원구    NaN
# 은평구    NaN
# 서대문구   NaN
# 마포구    NaN
# 양천구    NaN
# 강서구    NaN
# 구로구    NaN
# 금천구    NaN
# 영등포구   NaN
# 동작구    NaN
# 관악구    NaN
# 서초구    NaN
# 강남구    NaN
# 송파구    NaN
# 강동구    NaN
# dtype: float64

# %%
#합계
report.sum(axis=1, skipna=True)
# Out:
# 자치구
# 자치구       기간세대합계합계합계한국인한국인한국인등록외국인등록외국인등록외국인세대당인구65세이상고령자
# 자치구                      기간세대계남자여자계남자여자계남자여자세대당인구65세이상고령자
# 합계      20204,417,9549,911,0884,816,5225,094,5669,668,...
# 종로구     202075,003158,99676,87682,120149,38472,63576,7...
# 중구      202063,686134,63565,77668,859125,24061,22264,0...
# 용산구     2020113,093244,645118,835125,810230,040110,722...
# 성동구     2020135,870300,505146,424154,081293,556143,387...
# 광진구     2020167,427360,109173,000187,109346,682167,310...
# 동대문구    2020167,598357,014175,322181,692342,837169,769...
# 중랑구     2020185,920399,562197,118202,444394,702195,165...
# 성북구     2020195,396447,056214,658232,398437,153210,810...
# 강북구     2020145,896311,569151,466160,103308,055150,143...
# 도봉구     2020139,114327,361159,420167,941325,257158,620...
# 노원구     2020218,270527,032254,188272,844523,037252,383...
# 은평구     2020213,914484,043231,998252,045479,835230,279...
# 서대문구    2020144,838322,952153,152169,800312,173149,360...
# 마포구     2020178,482381,858178,977202,881371,890175,150...
# 양천구     2020180,633457,781224,379233,402454,251222,824...
# 강서구     2020266,982585,901282,686303,215580,185280,034...
# 구로구     2020180,531432,488215,424217,064404,408199,673...
# 금천구     2020114,715247,835126,141121,694231,733117,226...
# 영등포구    2020184,714407,367202,969204,398379,480187,647...
# 동작구     2020184,229401,572193,718207,854391,220189,152...
# 관악구     2020274,811509,803255,211254,592495,060248,339...
# 서초구     2020173,502429,025205,282223,743425,126203,359...
# 강남구     2020234,872544,055260,378283,677539,231257,999...
# 송파구     2020281,959673,926325,080348,846667,960322,299...
# 강동구     2020196,499463,998228,044235,954459,970226,216...
# dtype: object

# %%
#중위값
report.median(axis=1)
# Out:
# 자치구
# 자치구    NaN
# 자치구    NaN
# 합계     NaN
# 종로구    NaN
# 중구     NaN
# 용산구    NaN
# 성동구    NaN
# 광진구    NaN
# 동대문구   NaN
# 중랑구    NaN
# 성북구    NaN
# 강북구    NaN
# 도봉구    NaN
# 노원구    NaN
# 은평구    NaN
# 서대문구   NaN
# 마포구    NaN
# 양천구    NaN
# 강서구    NaN
# 구로구    NaN
# 금천구    NaN
# 영등포구   NaN
# 동작구    NaN
# 관악구    NaN
# 서초구    NaN
# 강남구    NaN
# 송파구    NaN
# 강동구    NaN
# dtype: float64

# %%
#표준편차
report.std(axis=1)
# Out:
# 자치구
# 자치구    NaN
# 자치구    NaN
# 합계     NaN
# 종로구    NaN
# 중구     NaN
# 용산구    NaN
# 성동구    NaN
# 광진구    NaN
# 동대문구   NaN
# 중랑구    NaN
# 성북구    NaN
# 강북구    NaN
# 도봉구    NaN
# 노원구    NaN
# 은평구    NaN
# 서대문구   NaN
# 마포구    NaN
# 양천구    NaN
# 강서구    NaN
# 구로구    NaN
# 금천구    NaN
# 영등포구   NaN
# 동작구    NaN
# 관악구    NaN
# 서초구    NaN
# 강남구    NaN
# 송파구    NaN
# 강동구    NaN
# dtype: float64

# %%
#분산
report.var(axis=1)
# Out:
# 자치구
# 자치구    NaN
# 자치구    NaN
# 합계     NaN
# 종로구    NaN
# 중구     NaN
# 용산구    NaN
# 성동구    NaN
# 광진구    NaN
# 동대문구   NaN
# 중랑구    NaN
# 성북구    NaN
# 강북구    NaN
# 도봉구    NaN
# 노원구    NaN
# 은평구    NaN
# 서대문구   NaN
# 마포구    NaN
# 양천구    NaN
# 강서구    NaN
# 구로구    NaN
# 금천구    NaN
# 영등포구   NaN
# 동작구    NaN
# 관악구    NaN
# 서초구    NaN
# 강남구    NaN
# 송파구    NaN
# 강동구    NaN
# dtype: float64

# %%
#데이터개수
report.count(axis=1)
# Out:
# 자치구
# 자치구     13
# 자치구     13
# 합계      13
# 종로구     13
# 중구      13
# 용산구     13
# 성동구     13
# 광진구     13
# 동대문구    13
# 중랑구     13
# 성북구     13
# 강북구     13
# 도봉구     13
# 노원구     13
# 은평구     13
# 서대문구    13
# 마포구     13
# 양천구     13
# 강서구     13
# 구로구     13
# 금천구     13
# 영등포구    13
# 동작구     13
# 관악구     13
# 서초구     13
# 강남구     13
# 송파구     13
# 강동구     13
# dtype: int64

# %%
#3
report.mean('외국인', '고령자')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     367         try:
# --> 368             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     369         except KeyError:
#
# KeyError: '외국인'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-8ba599349647> in <module>
#       1 #3
# ----> 2 report.mean('외국인', '고령자')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   11466         if level is not None:
#   11467             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
# > 11468         return self._reduce(
#   11469             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11470         )
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    8561         else:
#    8562             # TODO: Make other agg func handle axis=None properly
# -> 8563             axis = self._get_axis_number(axis)
#    8564             labels = self._get_agg_axis(axis)
#    8565             constructor = self._constructor
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     368             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     369         except KeyError:
# --> 370             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#     371
#     372     @classmethod
#
# ValueError: No axis named 외국인 for object type DataFrame

# %% [markdown]
# # DataFrame 병합하기
# ### seoul_cctv.csv 파일
# - 서울 자치구 연도별 CCTV 데이터 셋 [서울열린데이터광장](http://data.seoul.go.kr/dataList/OA-2734/C/1/datasetView.do)
#
#
# 1. seoul_cctv.csv 파일을 DataFrame으로 읽기
# 2. 서울시 자치구별 인구 DataFrame과 서울시 자치구 CCTV 데이터 셋을 **자치구명을 기준으로** 결합하여 하나의 DataFrame으로 만드시오.

# %%
cctv_df = pd.read_csv('seoul_cctv.xlsx', sep='\t', engine='python', encoding='cp949')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-73-c18324f79582> in <module>
# ----> 1 cctv_df = pd.read_csv('seoul_cctv.xlsx', sep='\t', engine='python', encoding='cp949')
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     944             self.options["has_index_names"] = kwds["has_index_names"]
#     945
# --> 946         self._make_engine(self.engine)
#     947
#     948     def close(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1187                     'are "c", "python", or "python-fwf")'
#    1188                 )
# -> 1189             self._engine = klass(self.f, **self.options)
#    1190
#    1191     def _failover_to_python(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, **kwds)
#    2403                 self.num_original_columns,
#    2404                 self.unnamed_cols,
# -> 2405             ) = self._infer_columns()
#    2406         except (TypeError, ValueError):
#    2407             self.close()
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _infer_columns(self)
#    2681             for level, hr in enumerate(header):
#    2682                 try:
# -> 2683                     line = self._buffered_line()
#    2684
#    2685                     while self.line_pos <= hr:
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _buffered_line(self)
#    2857             return self.buf[0]
#    2858         else:
# -> 2859             return self._next_line()
#    2860
#    2861     def _check_for_bom(self, first_row):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _next_line(self)
#    2954
#    2955             while True:
# -> 2956                 orig_line = self._next_iter_line(row_num=self.pos + 1)
#    2957                 self.pos += 1
#    2958
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _next_iter_line(self, row_num)
#    3012         """
#    3013         try:
# -> 3014             return next(self.data)
#    3015         except csv.Error as e:
#    3016             if self.warn_bad_lines or self.error_bad_lines:
#
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xa2 in position 50: illegal multibyte sequence

# %% [markdown]
# # Groupby와 집계
# ## forestfire.csv 파일
# - 포르투칼 북서부 산림 산불관련 데이터 셋 [UCI Machine learning repository](https://archive.ics.uci.edu/ml/datasets/forest+fires)
#
#
# 1. forestfire.csv 파일을 DataFrame으로 읽기
# 1. 어떤 컬럼들이 범주형 컬럼인지 확인.
# 1. 월(month)과 요일(day) 의 고유한(unique) 값들과 각각의 행수 조회
# 1. 요일(day) 별 wind의 평균을 조회
# 1. 요일(day) 별 wind, rain의 평균을 조회
# 1. 요일(day) 별 wind, rain의 평균과 합계과 개수 조회
# 1. 요일(day) 별로 wind는 평균을 rain은 합계와 최대값을 조회
# 1. 월(month) 그리고 요일별(day) temp의 최대값과 최소값을 조회
# 1. X좌표(X), Y좌표(Y)별 temp의 평균울 pivot table로 조회

# %%
fire_df = pd.read_csv('forestfires.csv')
